# %%
with open("nbaallelo.csv", "r") as file:
    lines = file.readlines()

data = [line.strip().split(",") for line in lines]

header = data[0]

for i in range(1, len(data)): 
    row = data[i]
    team_id = row[header.index("team_id")]
    if team_id == "LAL": 
        print(row)
# Out:
# ['4866', '196010190CIN', 'NBA', '1', '1961', '10/19/1960', '1', '0', 'LAL', 'Lakers', '123', '1472.1079', '1456.235', '35.369419', 'CIN', 'Kings', '140', '1349.7457', '1365.6187', 'A', 'L', '0.53213739', '']
# ['4870', '196010220STL', 'NBA', '1', '1961', '10/22/1960', '2', '0', 'LAL', 'Lakers', '96', '1456.235', '1450.4137', '34.771576', 'STL', 'Hawks', '112', '1556.3074', '1562.1287', 'A', 'L', '0.24017704', '']
# ['4873', '196010240LAL', 'NBA', '0', '1961', '10/24/1960', '3', '0', 'LAL', 'Lakers', '101', '1450.4137', '1435.3485', '33.237518', 'NYK', 'Knicks', '111', '1435.7505', '1450.8157', 'H', 'L', '0.65927261', '']
# ['4874', '196010250LAL', 'NBA', '0', '1961', '10/25/1960', '4', '0', 'LAL', 'Lakers', '120', '1435.3485', '1438.7944', '33.586594', 'NYK', 'Knicks', '118', '1450.8157', '1447.3698', 'H', 'W', '0.61930752', '']
# ...
