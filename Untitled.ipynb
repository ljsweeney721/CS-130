# %%
import pandas as pd
df= pd.read_csv("nbaallelo.csv")

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
# 3  1300.0000  1309.6521              A            L  0.368899   NaN
# 4  1300.0000  1320.3811              H            L  0.640065   NaN
#
# [5 rows x 23 columns]

# %%
df['opp_pts']
# Out:
# 0          68
# 1          66
# 2          47
# 3          63
# 4          50
#          ...
# 126309    103
# 126310     91
# 126311    104
# 126312    105
# 126313     97
# Name: opp_pts, Length: 126314, dtype: int64

# %%
df.loc[(df.opp_pts > 150) & (df.is_playoffs > 0)]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 21313      10657  197003300PHI   NBA        0     1970  3/30/1970          85
# 49527      24764  198304260SAS   NBA        1     1983  4/26/1983          86
# 53638      26820  198505220LAL   NBA        1     1985  5/22/1985          97
# 57562      28782  198704230DAL   NBA        1     1987  4/23/1987          83
# 64152      32077  199004280BOS   NBA        1     1990  4/28/1990          84
# 68934      34468  199205110PHO   NBA        0     1992  5/11/1992          89
# 68935      34468  199205110PHO   NBA        1     1992  5/11/1992          90
#
#        is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 21313            1     PHI        Sixers  ...  43.802334     MIL
# 49527            1     DEN       Nuggets  ...  47.912365     SAS
# 53638            1     DEN       Nuggets  ...  51.957233     LAL
# 57562            1     SEA       Thunder  ...  39.382092     DAL
# 64152            1     NYK        Knicks  ...  37.150238     BOS
# 68934            1     PHO          Suns  ...  55.029408     POR
# 68935            1     POR  Trailblazers  ...  59.259548     PHO
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  \
# 21313         Bucks      156  1569.5912  1598.9172              H
# 49527         Spurs      152  1612.3881  1621.2742              A
# 53638        Lakers      153  1740.8021  1751.5950              A
# 57562     Mavericks      151  1617.8680  1624.2948              A
# 64152       Celtics      157  1610.4678  1616.8213              A
# 68934  Trailblazers      153  1670.8611  1676.8859              H
# 68935          Suns      151  1635.0959  1629.0712              A
#
#        game_result  forecast notes
# 21313            L  0.565301   NaN
# 49527            L  0.311958   NaN
# 53638            L  0.218874   NaN
# 57562            L  0.216342   NaN
# 64152            L  0.180256   NaN
# 68934            L  0.591402   NaN
# 68935            W  0.408598   NaN
#
# [7 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df['new_column'] = df['fran_id'] / df['team_id']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['new_column'] = df['fran_id'] / df['team_id']
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
df.game_result.describe()
# Out:
# count     126314
# unique         2
# top            L
# freq       63157
# Name: game_result, dtype: object

# %%
df.game_result.value_counts()
# Out:
# game_result
# L    63157
# W    63157
# Name: count, dtype: int64

# %%
df.opp_pts.plot(kind='hist')
plt.title('Wins Vs Location')
plt.xlabel('Wins')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 df.opp_pts.plot(kind='hist')
# ----> 2 plt.title('Wins Vs Location')
#       3 plt.xlabel('Wins')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.opp_pts.plot( x='Opposing Teams Points', y='Times it happenedd', figsize=(12,6), )
plt.title('Games')
plt.xlabel('Number of Points')
plt.ylabel('Times it happened')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 df.opp_pts.plot( x='Opposing Teams Points', y='Times it happenedd', figsize=(12,6), )
# ----> 2 plt.title('Games')
#       3 plt.xlabel('Number of Points')
#       4 plt.ylabel('Times it happened')
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("nbaallelo.csv")

df['decade'] = (df['year_id'] // 10) * 10


df['win'] = df['game_result'].apply(lambda x: 1 if x == 'W' else 0)

print(df[['year_id', 'decade', 'game_result', 'win']].head())
# Out:
#    year_id  decade game_result  win
# 0     1947    1940           L    0
# 1     1947    1940           W    1
# 2     1947    1940           W    1
# 3     1947    1940           L    0
# 4     1947    1940           L    0

# %%
# Group home games by decade
grouped = home_games.groupby('decade')

# Take the average of the win column inside each group
win_rates_series = grouped['win'].mean()

print("Home Win Percentages :")
print(win_percentages)
# Out:
# Home Win Percentages :
# decade
# 1940    60.846561
# 1950    65.674548
# 1960    60.550996
# 1970    63.783109
# 1980    64.816650
# 1990    61.781634
# 2000    60.801488
# 2010    59.489194
# Name: win, dtype: float64
